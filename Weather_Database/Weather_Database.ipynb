# %%
#import the dependencies 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np
import requests 
from config import weather_api_key
from citipy import citipy

# %%
#create a set of random latitdue and longitude comninations 
lats = np.random.uniform(low = -90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low = 180.000, high = 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#starting URL for weather Map API Call.
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a76512f1b7f80ce6ab8b33895d66a0f

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 786

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | port elizabeth
# Processing Record 2 of Set 1 | atuona
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | lorengau
# Processing Record 5 of Set 1 | souillac
# Processing Record 6 of Set 1 | karpuninskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | sebring
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | buchanan
# Processing Record 12 of Set 1 | mahebourg
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 1 | nicoya
# Processing Record 17 of Set 1 | butaritari
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | itarema
# Processing Record 21 of Set 1 | port alfred
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | bredasdorp
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | berlevag
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | yar-sale
# Processing Record 30 of Set 1 | yumen
# Processing Record 31 of Set 1 | lavrentiya
# Processing Record 32 of Set 1 | qandala
# Processing Record 33 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 34 of Set 1 | victoria
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | georgetown
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | kupang
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | west bay
# Processing Record 41 of Set 1 | egvekinot
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | chuy
# Processing Record 44 of Set 1 | arcachon
# Processing Record 45 of Set 1 | san policarpo
# Processing Record 46 of Set 1 | whitley bay
# Processing Record 47 of Set 1 | susehri
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | coahuayana
# Processing Record 50 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 1 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 2 | new berlin
# Processing Record 3 of Set 2 | port blair
# Processing Record 4 of Set 2 | sur
# Processing Record 5 of Set 2 | sitka
# Processing Record 6 of Set 2 | leningradskiy
# Processing Record 7 of Set 2 | kawalu
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | yerofey pavlovich
# Processing Record 10 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 2 | jamestown
# Processing Record 12 of Set 2 | acajutla
# Processing Record 13 of Set 2 | port macquarie
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | onguday
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | lompoc
# Processing Record 18 of Set 2 | westport
# Processing Record 19 of Set 2 | faanui
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | tutoia
# Processing Record 22 of Set 2 | constitucion
# Processing Record 23 of Set 2 | muli
# Processing Record 24 of Set 2 | cuencame
# Processing Record 25 of Set 2 | vung tau
# Processing Record 26 of Set 2 | karasburg
# Processing Record 27 of Set 2 | kerema
# Processing Record 28 of Set 2 | sechura
# Processing Record 29 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 2 | itaqui
# Processing Record 31 of Set 2 | molchanovo
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | nizhniy odes
# Processing Record 34 of Set 2 | thompson
# Processing Record 35 of Set 2 | mathbaria
# Processing Record 36 of Set 2 | saskylakh
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | grindavik
# Processing Record 39 of Set 2 | aden
# Processing Record 40 of Set 2 | batticaloa
# Processing Record 41 of Set 2 | san cristobal
# Processing Record 42 of Set 2 | narsaq
# Processing Record 43 of Set 2 | zlatoustovsk
# City not found. Skipping...
# Processing Record 44 of Set 2 | ponta do sol
# Processing Record 45 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 2 | mar del plata
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | cabo san lucas
# Processing Record 49 of Set 2 | tiksi
# Processing Record 50 of Set 2 | butembo
# Processing Record 1 of Set 3 | milton keynes
# Processing Record 2 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 3 | pitimbu
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | skjaerhollen
# City not found. Skipping...
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | pevek
# Processing Record 8 of Set 3 | bilibino
# Processing Record 9 of Set 3 | bairnsdale
# Processing Record 10 of Set 3 | puerto narino
# Processing Record 11 of Set 3 | salinas
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | richards bay
# Processing Record 14 of Set 3 | basco
# Processing Record 15 of Set 3 | balkanabat
# Processing Record 16 of Set 3 | ribeira grande
# Processing Record 17 of Set 3 | new norfolk
# Processing Record 18 of Set 3 | brae
# Processing Record 19 of Set 3 | kapaa
# Processing Record 20 of Set 3 | dali
# Processing Record 21 of Set 3 | pacific grove
# Processing Record 22 of Set 3 | nantucket
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | menongue
# Processing Record 27 of Set 3 | quatre cocos
# Processing Record 28 of Set 3 | abu kamal
# Processing Record 29 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 3 | victor harbor
# Processing Record 31 of Set 3 | kodiak
# City not found. Skipping...
# Processing Record 32 of Set 3 | tallahassee
# Processing Record 33 of Set 3 | kyabram
# Processing Record 34 of Set 3 | marawi
# Processing Record 35 of Set 3 | den helder
# Processing Record 36 of Set 3 | vila franca do campo
# Processing Record 37 of Set 3 | lamar
# Processing Record 38 of Set 3 | kulevcha
# Processing Record 39 of Set 3 | landau
# Processing Record 40 of Set 3 | saint-joseph
# Processing Record 41 of Set 3 | kavieng
# Processing Record 42 of Set 3 | gariaband
# Processing Record 43 of Set 3 | kirkland lake
# Processing Record 44 of Set 3 | jumla
# Processing Record 45 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 3 | roma
# Processing Record 47 of Set 3 | stanghelle
# Processing Record 48 of Set 3 | hambantota
# Processing Record 49 of Set 3 | preeceville
# Processing Record 50 of Set 3 | namibe
# Processing Record 1 of Set 4 | ostrovnoy
# Processing Record 2 of Set 4 | kenora
# Processing Record 3 of Set 4 | kutum
# Processing Record 4 of Set 4 | hami
# Processing Record 5 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 6 of Set 4 | kaffrine
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | nakapiripirit
# Processing Record 9 of Set 4 | nikolskoye
# Processing Record 10 of Set 4 | rocha
# Processing Record 11 of Set 4 | mbuji-mayi
# Processing Record 12 of Set 4 | axim
# Processing Record 13 of Set 4 | koumac
# City not found. Skipping...
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | puksoozero
# Processing Record 16 of Set 4 | khudumelapye
# Processing Record 17 of Set 4 | zeya
# Processing Record 18 of Set 4 | zwedru
# Processing Record 19 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | tilichiki
# Processing Record 22 of Set 4 | businga
# Processing Record 23 of Set 4 | niquero
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | chokurdakh
# Processing Record 26 of Set 4 | krapivinskiy
# Processing Record 27 of Set 4 | mecca
# Processing Record 28 of Set 4 | tual
# Processing Record 29 of Set 4 | carbondale
# Processing Record 30 of Set 4 | mooi river
# City not found. Skipping...
# Processing Record 31 of Set 4 | kindu
# Processing Record 32 of Set 4 | rohri
# Processing Record 33 of Set 4 | minudasht
# Processing Record 34 of Set 4 | buala
# Processing Record 35 of Set 4 | nuuk
# Processing Record 36 of Set 4 | linqiong
# Processing Record 37 of Set 4 | klaksvik
# Processing Record 38 of Set 4 | kieta
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | pisco
# Processing Record 41 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 4 | miramar
# Processing Record 44 of Set 4 | praia da vitoria
# Processing Record 45 of Set 4 | kisesa
# Processing Record 46 of Set 4 | san francisco
# Processing Record 47 of Set 4 | allonnes
# Processing Record 48 of Set 4 | abu samrah
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | visby
# Processing Record 1 of Set 5 | sukhumi
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | flin flon
# Processing Record 4 of Set 5 | nishihara
# Processing Record 5 of Set 5 | iquitos
# Processing Record 6 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 5 | milton
# Processing Record 8 of Set 5 | hofn
# Processing Record 9 of Set 5 | anloga
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | beira
# Processing Record 12 of Set 5 | simbahan
# Processing Record 13 of Set 5 | hirara
# Processing Record 14 of Set 5 | loukhi
# Processing Record 15 of Set 5 | san martin
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | saint-philippe
# Processing Record 18 of Set 5 | chattanooga
# Processing Record 19 of Set 5 | norman wells
# Processing Record 20 of Set 5 | sandovo
# Processing Record 21 of Set 5 | bollnas
# City not found. Skipping...
# Processing Record 22 of Set 5 | ketchikan
# Processing Record 23 of Set 5 | chara
# Processing Record 24 of Set 5 | sivaki
# Processing Record 25 of Set 5 | nhulunbuy
# Processing Record 26 of Set 5 | polunochnoye
# Processing Record 27 of Set 5 | zhangjiakou
# Processing Record 28 of Set 5 | svetlogorsk
# Processing Record 29 of Set 5 | vardo
# Processing Record 30 of Set 5 | kaitangata
# Processing Record 31 of Set 5 | dharmavaram
# Processing Record 32 of Set 5 | bonavista
# Processing Record 33 of Set 5 | isangel
# Processing Record 34 of Set 5 | usinsk
# Processing Record 35 of Set 5 | bafq
# Processing Record 36 of Set 5 | troitskoye
# Processing Record 37 of Set 5 | hit
# Processing Record 38 of Set 5 | otavalo
# Processing Record 39 of Set 5 | inhambane
# Processing Record 40 of Set 5 | balgazyn
# Processing Record 41 of Set 5 | nanortalik
# Processing Record 42 of Set 5 | jishou
# Processing Record 43 of Set 5 | sembakung
# Processing Record 44 of Set 5 | talnakh
# Processing Record 45 of Set 5 | ostersund
# Processing Record 46 of Set 5 | mitsamiouli
# Processing Record 47 of Set 5 | viedma
# Processing Record 48 of Set 5 | kuhdasht
# Processing Record 49 of Set 5 | taoudenni
# Processing Record 50 of Set 5 | bambous virieux
# Processing Record 1 of Set 6 | kilindoni
# Processing Record 2 of Set 6 | bonga
# Processing Record 3 of Set 6 | burica
# City not found. Skipping...
# Processing Record 4 of Set 6 | beian
# Processing Record 5 of Set 6 | jaguaruna
# Processing Record 6 of Set 6 | koungou
# Processing Record 7 of Set 6 | grand gaube
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | una
# Processing Record 10 of Set 6 | rongcheng
# Processing Record 11 of Set 6 | dzerzhinsk
# Processing Record 12 of Set 6 | tabulbah
# City not found. Skipping...
# Processing Record 13 of Set 6 | tasiilaq
# Processing Record 14 of Set 6 | inuvik
# Processing Record 15 of Set 6 | kurilsk
# Processing Record 16 of Set 6 | madimba
# Processing Record 17 of Set 6 | bethel
# Processing Record 18 of Set 6 | havre-saint-pierre
# Processing Record 19 of Set 6 | luderitz
# Processing Record 20 of Set 6 | husavik
# Processing Record 21 of Set 6 | bandarbeyla
# Processing Record 22 of Set 6 | seminole
# City not found. Skipping...
# Processing Record 23 of Set 6 | linxia
# City not found. Skipping...
# Processing Record 24 of Set 6 | provideniya
# City not found. Skipping...
# Processing Record 25 of Set 6 | road town
# Processing Record 26 of Set 6 | santa teresa
# City not found. Skipping...
# Processing Record 27 of Set 6 | kirakira
# City not found. Skipping...
# Processing Record 28 of Set 6 | chumikan
# City not found. Skipping...
# Processing Record 29 of Set 6 | dudinka
# Processing Record 30 of Set 6 | shache
# City not found. Skipping...
# Processing Record 31 of Set 6 | anandnagar
# City not found. Skipping...
# Processing Record 32 of Set 6 | faya
# Processing Record 33 of Set 6 | wallasey
# City not found. Skipping...
# Processing Record 34 of Set 6 | lubango
# City not found. Skipping...
# Processing Record 35 of Set 6 | asau
# Processing Record 36 of Set 6 | marzuq
# City not found. Skipping...
# Processing Record 37 of Set 6 | podgornoye
# Processing Record 38 of Set 6 | russell
# City not found. Skipping...
# Processing Record 39 of Set 6 | varska
# City not found. Skipping...
# Processing Record 40 of Set 6 | san vicente
# City not found. Skipping...
# Processing Record 41 of Set 6 | puerto colombia
# Processing Record 42 of Set 6 | san patricio
# City not found. Skipping...
# Processing Record 43 of Set 6 | xining
# City not found. Skipping...
# Processing Record 44 of Set 6 | baykit
# Processing Record 45 of Set 6 | kuching
# City not found. Skipping...
# Processing Record 46 of Set 6 | ukholovo
# City not found. Skipping...
# Processing Record 47 of Set 6 | saint george
# Processing Record 48 of Set 6 | mount gambier
# City not found. Skipping...
# Processing Record 49 of Set 6 | natchitoches
# Processing Record 50 of Set 6 | carnarvon
# Processing Record 1 of Set 7 | sola
# Processing Record 2 of Set 7 | soe
# Processing Record 3 of Set 7 | sobolevo
# City not found. Skipping...
# Processing Record 4 of Set 7 | tautira
# Processing Record 5 of Set 7 | ambon
# Processing Record 6 of Set 7 | touros
# Processing Record 7 of Set 7 | agadez
# Processing Record 8 of Set 7 | tessalit
# Processing Record 9 of Set 7 | nylstroom
# City not found. Skipping...
# Processing Record 10 of Set 7 | general roca
# Processing Record 11 of Set 7 | sweetwater
# Processing Record 12 of Set 7 | baoqing
# Processing Record 13 of Set 7 | lodwar
# Processing Record 14 of Set 7 | miedzyrzec podlaski
# Processing Record 15 of Set 7 | staraya poltavka
# Processing Record 16 of Set 7 | ezhou
# Processing Record 17 of Set 7 | luancheng
# Processing Record 18 of Set 7 | severo-yeniseyskiy
# Processing Record 19 of Set 7 | lianzhou
# Processing Record 20 of Set 7 | candawaga
# City not found. Skipping...
# Processing Record 21 of Set 7 | santiago
# Processing Record 22 of Set 7 | tari
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | vestmannaeyjar
# Processing Record 25 of Set 7 | houston
# Processing Record 26 of Set 7 | flinders
# Processing Record 27 of Set 7 | dryden
# Processing Record 28 of Set 7 | mahabad
# City not found. Skipping...
# Processing Record 29 of Set 7 | abapo
# Processing Record 30 of Set 7 | ariquemes
# City not found. Skipping...
# Processing Record 31 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 7 | berbera
# City not found. Skipping...
# Processing Record 33 of Set 7 | dharmapuri
# City not found. Skipping...
# Processing Record 34 of Set 7 | komsomolskiy
# Processing Record 35 of Set 7 | saryshagan
# City not found. Skipping...
# Processing Record 36 of Set 7 | barrow
# Processing Record 37 of Set 7 | huilong
# Processing Record 38 of Set 7 | tazovskiy
# City not found. Skipping...
# Processing Record 39 of Set 7 | matagami
# City not found. Skipping...
# Processing Record 40 of Set 7 | carnduff
# City not found. Skipping...
# Processing Record 41 of Set 7 | santa isabel
# Processing Record 42 of Set 7 | trelew
# City not found. Skipping...
# Processing Record 43 of Set 7 | walvis bay
# City not found. Skipping...
# Processing Record 44 of Set 7 | sterling
# City not found. Skipping...
# Processing Record 45 of Set 7 | tuatapere
# Processing Record 46 of Set 7 | ankang
# City not found. Skipping...
# Processing Record 47 of Set 7 | kavaratti
# City not found. Skipping...
# Processing Record 48 of Set 7 | lebu
# City not found. Skipping...
# Processing Record 49 of Set 7 | ahipara
# City not found. Skipping...
# Processing Record 50 of Set 7 | coihaique
# City not found. Skipping...
# Processing Record 1 of Set 8 | sol-iletsk
# City not found. Skipping...
# Processing Record 2 of Set 8 | jiangyou
# City not found. Skipping...
# Processing Record 3 of Set 8 | ljubovija
# City not found. Skipping...
# Processing Record 4 of Set 8 | humaita
# City not found. Skipping...
# Processing Record 5 of Set 8 | nalut
# Processing Record 6 of Set 8 | ahuimanu
# City not found. Skipping...
# Processing Record 7 of Set 8 | punta alta
# City not found. Skipping...
# Processing Record 8 of Set 8 | agsu
# City not found. Skipping...
# Processing Record 9 of Set 8 | tunghsiao
# City not found. Skipping...
# Processing Record 10 of Set 8 | inta
# City not found. Skipping...
# Processing Record 11 of Set 8 | timbiqui
# City not found. Skipping...
# Processing Record 12 of Set 8 | umm kaddadah
# Processing Record 13 of Set 8 | coquimbo
# City not found. Skipping...
# Processing Record 14 of Set 8 | huejuquilla el alto
# City not found. Skipping...
# Processing Record 15 of Set 8 | charters towers
# City not found. Skipping...
# Processing Record 16 of Set 8 | tura
# Processing Record 17 of Set 8 | chalus
# City not found. Skipping...
# Processing Record 18 of Set 8 | boden
# City not found. Skipping...
# Processing Record 19 of Set 8 | yeniseysk
# City not found. Skipping...
# Processing Record 20 of Set 8 | pelym
# Processing Record 21 of Set 8 | cabra
# City not found. Skipping...
# Processing Record 22 of Set 8 | tshane
# Processing Record 23 of Set 8 | sumenep
# City not found. Skipping...
# Processing Record 24 of Set 8 | nyurba
# City not found. Skipping...
# Processing Record 25 of Set 8 | rumoi
# City not found. Skipping...
# Processing Record 26 of Set 8 | srednekolymsk
# Processing Record 27 of Set 8 | gerash
# City not found. Skipping...
# Processing Record 28 of Set 8 | sioux lookout
# City not found. Skipping...
# Processing Record 29 of Set 8 | kalmunai
# Processing Record 30 of Set 8 | westerland
# City not found. Skipping...
# Processing Record 31 of Set 8 | aktash
# City not found. Skipping...
# Processing Record 32 of Set 8 | jambi
# City not found. Skipping...
# Processing Record 33 of Set 8 | arraial do cabo
# Processing Record 34 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 8 | kouango
# City not found. Skipping...
# Processing Record 36 of Set 8 | muzhi
# City not found. Skipping...
# Processing Record 37 of Set 8 | poum
# Processing Record 38 of Set 8 | cairns
# City not found. Skipping...
# Processing Record 39 of Set 8 | juneau
# City not found. Skipping...
# Processing Record 40 of Set 8 | tundla
# City not found. Skipping...
# Processing Record 41 of Set 8 | tabas
# City not found. Skipping...
# Processing Record 42 of Set 8 | karauzyak
# City not found. Skipping...
# Processing Record 43 of Set 8 | alta floresta
# Processing Record 44 of Set 8 | isla mujeres
# City not found. Skipping...
# Processing Record 45 of Set 8 | padang
# City not found. Skipping...
# Processing Record 46 of Set 8 | sinjar
# City not found. Skipping...
# Processing Record 47 of Set 8 | lagoa
# City not found. Skipping...
# Processing Record 48 of Set 8 | honolulu
# Processing Record 49 of Set 8 | anadyr
# City not found. Skipping...
# Processing Record 50 of Set 8 | price
# City not found. Skipping...
# Processing Record 1 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 9 | maragogi
# Processing Record 3 of Set 9 | lamu
# City not found. Skipping...
# Processing Record 4 of Set 9 | effium
# City not found. Skipping...
# Processing Record 5 of Set 9 | sao filipe
# City not found. Skipping...
# Processing Record 6 of Set 9 | sheffield
# City not found. Skipping...
# Processing Record 7 of Set 9 | hasaki
# Processing Record 8 of Set 9 | oranjemund
# City not found. Skipping...
# Processing Record 9 of Set 9 | paamiut
# City not found. Skipping...
# Processing Record 10 of Set 9 | sofiysk
# City not found. Skipping...
# Processing Record 11 of Set 9 | matara
# Processing Record 12 of Set 9 | arlit
# City not found. Skipping...
# Processing Record 13 of Set 9 | kiomboi
# City not found. Skipping...
# Processing Record 14 of Set 9 | baturaja
# City not found. Skipping...
# Processing Record 15 of Set 9 | metu
# Processing Record 16 of Set 9 | saint anthony
# City not found. Skipping...
# Processing Record 17 of Set 9 | broome
# City not found. Skipping...
# Processing Record 18 of Set 9 | solnechnyy
# Processing Record 19 of Set 9 | ancud
# City not found. Skipping...
# Processing Record 20 of Set 9 | marsa matruh
# City not found. Skipping...
# Processing Record 21 of Set 9 | gunjur
# Processing Record 22 of Set 9 | mae sai
# Processing Record 23 of Set 9 | krasnoselkup
# Processing Record 24 of Set 9 | necochea
# Processing Record 25 of Set 9 | perris
# Processing Record 26 of Set 9 | buraydah
# City not found. Skipping...
# Processing Record 27 of Set 9 | najran
# City not found. Skipping...
# Processing Record 28 of Set 9 | hualmay
# Processing Record 29 of Set 9 | huarmey
# City not found. Skipping...
# Processing Record 30 of Set 9 | eijsden
# Processing Record 31 of Set 9 | nyrob
# Processing Record 32 of Set 9 | port-gentil
# Processing Record 33 of Set 9 | saint-raymond
# Processing Record 34 of Set 9 | nanga eboko
# Processing Record 35 of Set 9 | kaka
# Processing Record 36 of Set 9 | hovd
# Processing Record 37 of Set 9 | havelock
# Processing Record 38 of Set 9 | cedar city
# Processing Record 39 of Set 9 | calama
# Processing Record 40 of Set 9 | baherden
# Processing Record 41 of Set 9 | falkoping
# City not found. Skipping...
# Processing Record 42 of Set 9 | kahului
# City not found. Skipping...
# Processing Record 43 of Set 9 | bara
# City not found. Skipping...
# Processing Record 44 of Set 9 | pangnirtung
# City not found. Skipping...
# Processing Record 45 of Set 9 | portland
# Processing Record 46 of Set 9 | quelimane
# Processing Record 47 of Set 9 | ust-uda
# Processing Record 48 of Set 9 | lahaina
# Processing Record 49 of Set 9 | shizunai
# Processing Record 50 of Set 9 | talcahuano
# Processing Record 1 of Set 10 | vao
# Processing Record 2 of Set 10 | kultayevo
# Processing Record 3 of Set 10 | lang son
# Processing Record 4 of Set 10 | henties bay
# Processing Record 5 of Set 10 | kytlym
# City not found. Skipping...
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | halifax
# Processing Record 8 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 10 | camacha
# Processing Record 10 of Set 10 | eucaliptus
# Processing Record 11 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 10 | culpeper
# Processing Record 13 of Set 10 | jining
# Processing Record 14 of Set 10 | peniche
# Processing Record 15 of Set 10 | lensk
# Processing Record 16 of Set 10 | lipin bor
# Processing Record 17 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 18 of Set 10 | olinda
# City not found. Skipping...
# Processing Record 19 of Set 10 | rabo de peixe
# Processing Record 20 of Set 10 | waipawa
# Processing Record 21 of Set 10 | tecoanapa
# Processing Record 22 of Set 10 | la tuque
# City not found. Skipping...
# Processing Record 23 of Set 10 | pecos
# Processing Record 24 of Set 10 | avera
# Processing Record 25 of Set 10 | namatanai
# Processing Record 26 of Set 10 | gravdal
# Processing Record 27 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 28 of Set 10 | tshikapa
# Processing Record 29 of Set 10 | birjand
# Processing Record 30 of Set 10 | tabuk
# Processing Record 31 of Set 10 | katsuura
# Processing Record 32 of Set 10 | bosaso
# Processing Record 33 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 34 of Set 10 | meadow lake
# Processing Record 35 of Set 10 | bushehr
# Processing Record 36 of Set 10 | presidencia roque saenz pena
# Processing Record 37 of Set 10 | pontes e lacerda
# Processing Record 38 of Set 10 | silver city
# City not found. Skipping...
# Processing Record 39 of Set 10 | chiredzi
# Processing Record 40 of Set 10 | pangai
# City not found. Skipping...
# Processing Record 41 of Set 10 | port hardy
# Processing Record 42 of Set 10 | mildura
# Processing Record 43 of Set 10 | boyolangu
# Processing Record 44 of Set 10 | saint-augustin
# City not found. Skipping...
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | balingasay
# Processing Record 47 of Set 10 | cove
# City not found. Skipping...
# Processing Record 48 of Set 10 | golden
# Processing Record 49 of Set 10 | hudson bay
# Processing Record 50 of Set 10 | clyde river
# City not found. Skipping...
# Processing Record 1 of Set 11 | queanbeyan
# Processing Record 2 of Set 11 | lavumisa
# Processing Record 3 of Set 11 | cherskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | sao joao da barra
# Processing Record 6 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 11 | berani
# Processing Record 8 of Set 11 | vaitape
# Processing Record 9 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 10 of Set 11 | cabo rojo
# Processing Record 11 of Set 11 | meulaboh
# City not found. Skipping...
# Processing Record 12 of Set 11 | salalah
# Processing Record 13 of Set 11 | mazagao
# City not found. Skipping...
# Processing Record 14 of Set 11 | atar
# City not found. Skipping...
# Processing Record 15 of Set 11 | esfarayen
# Processing Record 16 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 11 | ghanzi
# Processing Record 18 of Set 11 | mayo
# Processing Record 19 of Set 11 | taltal
# City not found. Skipping...
# Processing Record 20 of Set 11 | nome
# Processing Record 21 of Set 11 | port lincoln
# City not found. Skipping...
# Processing Record 22 of Set 11 | barmer
# Processing Record 23 of Set 11 | tres arroyos
# City not found. Skipping...
# Processing Record 24 of Set 11 | ziro
# City not found. Skipping...
# Processing Record 25 of Set 11 | sangar
# Processing Record 26 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 11 | anta
# Processing Record 28 of Set 11 | kwinana
# City not found. Skipping...
# Processing Record 29 of Set 11 | sardarpur
# Processing Record 30 of Set 11 | yangjiang
# City not found. Skipping...
# Processing Record 31 of Set 11 | mirnyy
# City not found. Skipping...
# Processing Record 32 of Set 11 | sao jose da coroa grande
# Processing Record 33 of Set 11 | puerto lopez
# City not found. Skipping...
# Processing Record 34 of Set 11 | nouadhibou
# City not found. Skipping...
# Processing Record 35 of Set 11 | haines junction
# City not found. Skipping...
# Processing Record 36 of Set 11 | shablykino
# Processing Record 37 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 11 | yulara
# City not found. Skipping...
# Processing Record 39 of Set 11 | saldanha
# Processing Record 40 of Set 11 | soyo
# City not found. Skipping...
# Processing Record 41 of Set 11 | hemnes
# City not found. Skipping...
# Processing Record 42 of Set 11 | kidal
# City not found. Skipping...
# Processing Record 43 of Set 11 | zhigansk
# Processing Record 44 of Set 11 | belyy yar
# Processing Record 45 of Set 11 | cayenne
# Processing Record 46 of Set 11 | fairview
# Processing Record 47 of Set 11 | the valley
# Processing Record 48 of Set 11 | juybar
# Processing Record 49 of Set 11 | maputo
# Processing Record 50 of Set 11 | sanok
# Processing Record 1 of Set 12 | aripuana
# Processing Record 2 of Set 12 | antsohihy
# Processing Record 3 of Set 12 | xichang
# Processing Record 4 of Set 12 | senneterre
# Processing Record 5 of Set 12 | mount isa
# Processing Record 6 of Set 12 | manyana
# Processing Record 7 of Set 12 | phangnga
# Processing Record 8 of Set 12 | meybod
# Processing Record 9 of Set 12 | reforma
# City not found. Skipping...
# Processing Record 10 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | ondjiva
# City not found. Skipping...
# Processing Record 13 of Set 12 | pacifica
# City not found. Skipping...
# Processing Record 14 of Set 12 | sarh
# City not found. Skipping...
# Processing Record 15 of Set 12 | moree
# Processing Record 16 of Set 12 | tromso
# City not found. Skipping...
# Processing Record 17 of Set 12 | pathein
# City not found. Skipping...
# Processing Record 18 of Set 12 | mantua
# Processing Record 19 of Set 12 | kashan
# City not found. Skipping...
# Processing Record 20 of Set 12 | eloy
# City not found. Skipping...
# Processing Record 21 of Set 12 | gobabis
# Processing Record 22 of Set 12 | monrovia
# Processing Record 23 of Set 12 | kruisfontein
# Processing Record 24 of Set 12 | winnenden
# Processing Record 25 of Set 12 | hilton head island
# Processing Record 26 of Set 12 | nakusp
# Processing Record 27 of Set 12 | carutapera
# Processing Record 28 of Set 12 | independence
# Processing Record 29 of Set 12 | atikokan
# Processing Record 30 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 12 | terrasini
# Processing Record 32 of Set 12 | pimentel
# Processing Record 33 of Set 12 | duz
# City not found. Skipping...
# Processing Record 34 of Set 12 | balaipungut
# Processing Record 35 of Set 12 | bacolod
# Processing Record 36 of Set 12 | tsumeb
# Processing Record 37 of Set 12 | porto-vecchio
# Processing Record 38 of Set 12 | wajima
# Processing Record 39 of Set 12 | araouane
# Processing Record 40 of Set 12 | ipixuna
# Processing Record 41 of Set 12 | igarka
# Processing Record 42 of Set 12 | guerrero negro
# Processing Record 43 of Set 12 | darnah
# Processing Record 44 of Set 12 | youghal
# Processing Record 45 of Set 12 | santa cruz
# Processing Record 46 of Set 12 | erzin
# Processing Record 47 of Set 12 | noumea
# Processing Record 48 of Set 12 | mwense
# Processing Record 49 of Set 12 | langxiang
# Processing Record 50 of Set 12 | groningen
# Processing Record 1 of Set 13 | porbandar
# Processing Record 2 of Set 13 | palu
# Processing Record 3 of Set 13 | yatou
# Processing Record 4 of Set 13 | innisfail
# Processing Record 5 of Set 13 | fujin
# Processing Record 6 of Set 13 | iki-burul
# Processing Record 7 of Set 13 | la romana
# Processing Record 8 of Set 13 | college
# Processing Record 9 of Set 13 | veydelevka
# Processing Record 10 of Set 13 | khorixas
# City not found. Skipping...
# Processing Record 11 of Set 13 | petropavlovsk-kamchatskiy
# City not found. Skipping...
# Processing Record 12 of Set 13 | coxquihui
# City not found. Skipping...
# Processing Record 13 of Set 13 | srivardhan
# City not found. Skipping...
# Processing Record 14 of Set 13 | pueblo nuevo
# City not found. Skipping...
# Processing Record 15 of Set 13 | san rafael
# Processing Record 16 of Set 13 | novaya zaimka
# City not found. Skipping...
# Processing Record 17 of Set 13 | qaqortoq
# Processing Record 18 of Set 13 | te anau
# Processing Record 19 of Set 13 | khiri mat
# Processing Record 20 of Set 13 | tottori
# Processing Record 21 of Set 13 | glinka
# Processing Record 22 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 13 | roswell
# Processing Record 24 of Set 13 | sokolo
# Processing Record 25 of Set 13 | mataram
# Processing Record 26 of Set 13 | sarkikaraagac
# Processing Record 27 of Set 13 | bilma
# Processing Record 28 of Set 13 | tahe
# Processing Record 29 of Set 13 | cabinda
# Processing Record 30 of Set 13 | nove mesto na morave
# Processing Record 31 of Set 13 | yuci
# Processing Record 32 of Set 13 | inirida
# Processing Record 33 of Set 13 | pauini
# Processing Record 34 of Set 13 | goderich
# Processing Record 35 of Set 13 | gat
# Processing Record 36 of Set 13 | altay
# Processing Record 37 of Set 13 | gurupi
# Processing Record 38 of Set 13 | daru
# Processing Record 39 of Set 13 | stryn
# Processing Record 40 of Set 13 | codrington
# Processing Record 41 of Set 13 | nyaunglebin
# Processing Record 42 of Set 13 | phan thiet
# Processing Record 43 of Set 13 | tadotsu
# Processing Record 44 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 45 of Set 13 | amuntai
# Processing Record 46 of Set 13 | atascadero
# Processing Record 47 of Set 13 | sampit
# Processing Record 48 of Set 13 | gushikawa
# Processing Record 49 of Set 13 | barrhead
# Processing Record 50 of Set 13 | popondetta
# Processing Record 1 of Set 14 | uyemskiy
# Processing Record 2 of Set 14 | huber heights
# Processing Record 3 of Set 14 | valparaiso
# City not found. Skipping...
# Processing Record 4 of Set 14 | jian
# City not found. Skipping...
# Processing Record 5 of Set 14 | rajanpur
# City not found. Skipping...
# Processing Record 6 of Set 14 | half moon bay
# City not found. Skipping...
# Processing Record 7 of Set 14 | kuusankoski
# City not found. Skipping...
# Processing Record 8 of Set 14 | alice springs
# Processing Record 9 of Set 14 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 10 of Set 14 | lokosovo
# City not found. Skipping...
# Processing Record 11 of Set 14 | chapais
# City not found. Skipping...
# Processing Record 12 of Set 14 | bowen
# Processing Record 13 of Set 14 | babu
# City not found. Skipping...
# Processing Record 14 of Set 14 | chabahar
# City not found. Skipping...
# Processing Record 15 of Set 14 | pandan
# City not found. Skipping...
# Processing Record 16 of Set 14 | hobyo
# City not found. Skipping...
# Processing Record 17 of Set 14 | naryan-mar
# City not found. Skipping...
# Processing Record 18 of Set 14 | paciran
# Processing Record 19 of Set 14 | sogdiondon
# City not found. Skipping...
# Processing Record 20 of Set 14 | san pedro
# Processing Record 21 of Set 14 | amapa
# Processing Record 22 of Set 14 | honiara
# Processing Record 23 of Set 14 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 14 | cruz alta
# Processing Record 25 of Set 14 | kozmodemyansk
# Processing Record 26 of Set 14 | umm lajj
# City not found. Skipping...
# Processing Record 27 of Set 14 | evanston
# Processing Record 28 of Set 14 | yeppoon
# Processing Record 29 of Set 14 | seymchan
# Processing Record 30 of Set 14 | portree
# Processing Record 31 of Set 14 | ulladulla
# Processing Record 32 of Set 14 | vanimo
# Processing Record 33 of Set 14 | ust-kuyga
# Processing Record 34 of Set 14 | santa rita
# Processing Record 35 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 36 of Set 14 | budingen
# Processing Record 37 of Set 14 | fonte boa
# Processing Record 38 of Set 14 | qixingtai
# Processing Record 39 of Set 14 | selfoss
# Processing Record 40 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 41 of Set 14 | stepnoye
# Processing Record 42 of Set 14 | turbat
# Processing Record 43 of Set 14 | kenai
# Processing Record 44 of Set 14 | vostok
# Processing Record 45 of Set 14 | hauterive
# Processing Record 46 of Set 14 | ngunguru
# Processing Record 47 of Set 14 | itaocara
# Processing Record 48 of Set 14 | marion
# Processing Record 49 of Set 14 | stamsund
# City not found. Skipping...
# Processing Record 50 of Set 14 | aleksandrov gay
# Processing Record 1 of Set 15 | port victoria
# Processing Record 2 of Set 15 | comodoro rivadavia
# Processing Record 3 of Set 15 | nelson bay
# Processing Record 4 of Set 15 | surt
# Processing Record 5 of Set 15 | palmer
# Processing Record 6 of Set 15 | whitehorse
# Processing Record 7 of Set 15 | riyadh
# Processing Record 8 of Set 15 | maceio
# Processing Record 9 of Set 15 | sambava
# Processing Record 10 of Set 15 | dukat
# Processing Record 11 of Set 15 | tres lagoas
# Processing Record 12 of Set 15 | vila velha
# Processing Record 13 of Set 15 | chuguyevka
# Processing Record 14 of Set 15 | zaysan
# Processing Record 15 of Set 15 | ilulissat
# Processing Record 16 of Set 15 | dunedin
# Processing Record 17 of Set 15 | oakdale
# Processing Record 18 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 19 of Set 15 | aktas
# Processing Record 20 of Set 15 | nouakchott
# Processing Record 21 of Set 15 | gacko
# Processing Record 22 of Set 15 | cleethorpes
# Processing Record 23 of Set 15 | yarim
# Processing Record 24 of Set 15 | bealanana
# Processing Record 25 of Set 15 | olkhovka
# Processing Record 26 of Set 15 | general pico
# Processing Record 27 of Set 15 | sinjah
# City not found. Skipping...
# Processing Record 28 of Set 15 | north battleford
# Processing Record 29 of Set 15 | conde
# Processing Record 30 of Set 15 | luganville
# Processing Record 31 of Set 15 | lasa
# Processing Record 32 of Set 15 | aswan
# Processing Record 33 of Set 15 | sibolga
# Processing Record 34 of Set 15 | kesova gora
# Processing Record 35 of Set 15 | san felipe
# Processing Record 36 of Set 15 | mumford
# Processing Record 37 of Set 15 | ambulu
# Processing Record 38 of Set 15 | ossora
# Processing Record 39 of Set 15 | saint-georges
# Processing Record 40 of Set 15 | fairbanks
# Processing Record 41 of Set 15 | pundaguitan
# Processing Record 42 of Set 15 | ust-tsilma
# Processing Record 43 of Set 15 | shimoda
# Processing Record 44 of Set 15 | boddam
# Processing Record 45 of Set 15 | puerto carreno
# Processing Record 46 of Set 15 | rabak
# Processing Record 47 of Set 15 | khandyga
# Processing Record 48 of Set 15 | ponca city
# Processing Record 49 of Set 15 | novikovo
# Processing Record 50 of Set 15 | lata
# Processing Record 1 of Set 16 | uwayl
# City not found. Skipping...
# Processing Record 2 of Set 16 | kaputa
# Processing Record 3 of Set 16 | sistranda
# Processing Record 4 of Set 16 | xuanhua
# Processing Record 5 of Set 16 | tungor
# Processing Record 6 of Set 16 | girne
# Processing Record 7 of Set 16 | salinopolis
# Processing Record 8 of Set 16 | orange
# Processing Record 9 of Set 16 | kyabe
# Processing Record 10 of Set 16 | inderborskiy
# City not found. Skipping...
# Processing Record 11 of Set 16 | praya
# Processing Record 12 of Set 16 | port hedland
# Processing Record 13 of Set 16 | huazolotitlan
# City not found. Skipping...
# Processing Record 14 of Set 16 | bridlington
# Processing Record 15 of Set 16 | kasongo-lunda
# Processing Record 16 of Set 16 | arrecife
# Processing Record 17 of Set 16 | corinto
# Processing Record 18 of Set 16 | racovita
# Processing Record 19 of Set 16 | rockhampton
# Processing Record 20 of Set 16 | maniitsoq
# Processing Record 21 of Set 16 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 16 | tiznit
# Processing Record 23 of Set 16 | ambovombe
# Processing Record 24 of Set 16 | mogadishu
# Processing Record 25 of Set 16 | otavi
# Processing Record 26 of Set 16 | barranca
# Processing Record 27 of Set 16 | san mateo del mar
# Processing Record 28 of Set 16 | male
# Processing Record 29 of Set 16 | antofagasta
# Processing Record 30 of Set 16 | jacareacanga
# Processing Record 31 of Set 16 | zhangye
# Processing Record 32 of Set 16 | tucuman
# Processing Record 33 of Set 16 | athabasca
# Processing Record 34 of Set 16 | wawa
# Processing Record 35 of Set 16 | semnan
# Processing Record 36 of Set 16 | kiama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port Elizabeth -33.9180   25.5701     66.20        82          75
# 1          Atuona  -9.8000 -139.0333     78.82        78          71
# 2         Iqaluit  63.7506  -68.5145    -14.01        64           1
# 3        Lorengau  -2.0226  147.2712     85.82        68          40
# 4        Souillac -20.5167   57.5167     78.80        83          75
# 5       Busselton -33.6500  115.3333     89.01        30           0
# 6         Sebring  27.4956  -81.4409     55.40        82           1
# 7          Torbay  47.6666  -52.7314     39.00       100          75
# 8        Buchanan   5.8808  -10.0467     75.20        94          20
# 9       Mahebourg -20.4081   57.7000     78.80        83          75
#
#    Wind Speed Country                 Date
# 0        3.44      ZA  2021-01-18 02:50:32
# 1       15.93      PF  2021-01-18 02:50:33
# 2        4.65      CA  2021-01-18 02:50:33
# 3       13.87      PG  2021-01-18 02:50:33
# 4       11.50      MU  2021-01-18 02:46:49
# 5        5.99      AU  2021-01-18 02:50:34
# 6        3.44      US  2021-01-18 02:50:34
# 7       20.71      CA  2021-01-18 02:50:35
# 8        4.29      LR  2021-01-18 02:47:37
# 9       11.50      MU  2021-01-18 02:50:35

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
