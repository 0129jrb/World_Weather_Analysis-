# %%
#import the dependencies 
import pandas as pd 
import requests 
from config import weather_api_key
from citipy import citipy

# %%
#create a set of random latitdue and longitude comninations 
lats = np.random.uniform(low = -90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low = 180.000, high = 180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
#starting URL for weather Map API Call.
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Import the datetime module from the datetime library.
from datetime import datetime
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=0a76512f1b7f80ce6ab8b33895d66a0f

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 757

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | nikolskoye
# Processing Record 3 of Set 1 | gedo
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | oranjemund
# Processing Record 6 of Set 1 | jamestown
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | inhambane
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | port blair
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | pevek
# Processing Record 13 of Set 1 | ketchikan
# Processing Record 14 of Set 1 | guozhen
# Processing Record 15 of Set 1 | danville
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | shinichi
# Processing Record 19 of Set 1 | georgetown
# Processing Record 20 of Set 1 | ahipara
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | klaksvik
# Processing Record 24 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 26 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 27 of Set 1 | muncar
# City not found. Skipping...
# Processing Record 28 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 29 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 30 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 31 of Set 1 | kavieng
# City not found. Skipping...
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | east london
# Processing Record 34 of Set 1 | leh
# Processing Record 35 of Set 1 | atuona
# Processing Record 36 of Set 1 | wajima
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | bredasdorp
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | hamilton
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | chesapeake
# Processing Record 45 of Set 1 | kodiak
# Processing Record 46 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 1 | moses lake
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | paamiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | havre-saint-pierre
# Processing Record 2 of Set 2 | maningrida
# City not found. Skipping...
# Processing Record 3 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 4 of Set 2 | coquimbo
# City not found. Skipping...
# Processing Record 5 of Set 2 | eregli
# Processing Record 6 of Set 2 | den helder
# City not found. Skipping...
# Processing Record 7 of Set 2 | ilebo
# Processing Record 8 of Set 2 | marshall
# Processing Record 9 of Set 2 | isiro
# Processing Record 10 of Set 2 | padang
# Processing Record 11 of Set 2 | bambous virieux
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | chumikan
# Processing Record 14 of Set 2 | villaviciosa
# Processing Record 15 of Set 2 | lazaro cardenas
# Processing Record 16 of Set 2 | gambissara
# Processing Record 17 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 2 | palmer
# Processing Record 19 of Set 2 | ostrovnoy
# Processing Record 20 of Set 2 | joshimath
# Processing Record 21 of Set 2 | kholodnyy
# Processing Record 22 of Set 2 | batagay
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | kungurtug
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | havoysund
# Processing Record 27 of Set 2 | nome
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | bocana de paiwas
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | provideniya
# Processing Record 32 of Set 2 | bethel
# Processing Record 33 of Set 2 | hofn
# Processing Record 34 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 2 | walvis bay
# Processing Record 36 of Set 2 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | thinadhoo
# Processing Record 39 of Set 2 | ishigaki
# Processing Record 40 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 2 | aizkraukle
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | ucluelet
# Processing Record 44 of Set 2 | dolinsk
# Processing Record 45 of Set 2 | poum
# Processing Record 46 of Set 2 | santa rita
# Processing Record 47 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 2 | saint-philippe
# Processing Record 49 of Set 2 | bria
# Processing Record 50 of Set 2 | santa cruz
# Processing Record 1 of Set 3 | chicago
# Processing Record 2 of Set 3 | kuusamo
# Processing Record 3 of Set 3 | whitehorse
# Processing Record 4 of Set 3 | qaanaaq
# Processing Record 5 of Set 3 | lakes entrance
# Processing Record 6 of Set 3 | hami
# Processing Record 7 of Set 3 | rocha
# Processing Record 8 of Set 3 | xiongyue
# Processing Record 9 of Set 3 | anito
# Processing Record 10 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 3 | flinders
# Processing Record 12 of Set 3 | khed brahma
# Processing Record 13 of Set 3 | salalah
# Processing Record 14 of Set 3 | ambovombe
# Processing Record 15 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 3 | serebryansk
# Processing Record 17 of Set 3 | roswell
# Processing Record 18 of Set 3 | hadishahr
# Processing Record 19 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 3 | ekhabi
# Processing Record 21 of Set 3 | obo
# Processing Record 22 of Set 3 | sept-iles
# Processing Record 23 of Set 3 | santa marta
# Processing Record 24 of Set 3 | gilbues
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | caravelas
# Processing Record 27 of Set 3 | pangnirtung
# Processing Record 28 of Set 3 | faanui
# Processing Record 29 of Set 3 | the pas
# Processing Record 30 of Set 3 | almora
# Processing Record 31 of Set 3 | kloulklubed
# Processing Record 32 of Set 3 | gamba
# Processing Record 33 of Set 3 | la plata
# Processing Record 34 of Set 3 | gerash
# Processing Record 35 of Set 3 | maarianhamina
# Processing Record 36 of Set 3 | talnakh
# Processing Record 37 of Set 3 | lasa
# Processing Record 38 of Set 3 | kurtalan
# Processing Record 39 of Set 3 | vestmannaeyjar
# Processing Record 40 of Set 3 | cockburn town
# Processing Record 41 of Set 3 | carnarvon
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | chuka
# Processing Record 44 of Set 3 | marsa matruh
# Processing Record 45 of Set 3 | manokwari
# Processing Record 46 of Set 3 | victoria point
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | severo-yeniseyskiy
# Processing Record 49 of Set 3 | ribeira grande
# Processing Record 50 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 4 | hithadhoo
# Processing Record 2 of Set 4 | geraldton
# Processing Record 3 of Set 4 | flic en flac
# Processing Record 4 of Set 4 | belaya gora
# Processing Record 5 of Set 4 | shu
# Processing Record 6 of Set 4 | kalabo
# Processing Record 7 of Set 4 | betare oya
# Processing Record 8 of Set 4 | tuatapere
# Processing Record 9 of Set 4 | ambunti
# Processing Record 10 of Set 4 | chuy
# Processing Record 11 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | mandalgovi
# Processing Record 14 of Set 4 | daru
# Processing Record 15 of Set 4 | hovd
# Processing Record 16 of Set 4 | cidreira
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | baykit
# Processing Record 20 of Set 4 | yulara
# Processing Record 21 of Set 4 | norman wells
# Processing Record 22 of Set 4 | payo
# Processing Record 23 of Set 4 | bengkulu
# Processing Record 24 of Set 4 | kasungu
# Processing Record 25 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 4 | coihaique
# Processing Record 27 of Set 4 | udalguri
# Processing Record 28 of Set 4 | bullingen
# City not found. Skipping...
# Processing Record 29 of Set 4 | antalaha
# Processing Record 30 of Set 4 | vila velha
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | tondano
# Processing Record 33 of Set 4 | casablanca
# Processing Record 34 of Set 4 | rigaud
# Processing Record 35 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 36 of Set 4 | matagami
# Processing Record 37 of Set 4 | praia da vitoria
# Processing Record 38 of Set 4 | lorsch
# Processing Record 39 of Set 4 | deputatskiy
# Processing Record 40 of Set 4 | iskateley
# Processing Record 41 of Set 4 | krasnoselkup
# Processing Record 42 of Set 4 | portland
# Processing Record 43 of Set 4 | hanzhong
# Processing Record 44 of Set 4 | torbay
# Processing Record 45 of Set 4 | saldanha
# Processing Record 46 of Set 4 | marsh harbour
# Processing Record 47 of Set 4 | alofi
# Processing Record 48 of Set 4 | naifaru
# Processing Record 49 of Set 4 | ust-tsilma
# Processing Record 50 of Set 4 | naze
# Processing Record 1 of Set 5 | san patricio
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | rodrigues alves
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | manaure
# Processing Record 6 of Set 5 | zeya
# Processing Record 7 of Set 5 | westport
# Processing Record 8 of Set 5 | presidencia roque saenz pena
# Processing Record 9 of Set 5 | khatanga
# Processing Record 10 of Set 5 | kaitangata
# Processing Record 11 of Set 5 | gillette
# Processing Record 12 of Set 5 | fukue
# Processing Record 13 of Set 5 | muromtsevo
# Processing Record 14 of Set 5 | hermanus
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | nhulunbuy
# Processing Record 17 of Set 5 | solsvik
# City not found. Skipping...
# Processing Record 18 of Set 5 | kilindoni
# Processing Record 19 of Set 5 | chai nat
# Processing Record 20 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 5 | morristown
# Processing Record 22 of Set 5 | henties bay
# Processing Record 23 of Set 5 | snyder
# Processing Record 24 of Set 5 | victor harbor
# Processing Record 25 of Set 5 | pipar
# Processing Record 26 of Set 5 | fethiye
# Processing Record 27 of Set 5 | antofagasta
# Processing Record 28 of Set 5 | shache
# Processing Record 29 of Set 5 | cabo san lucas
# Processing Record 30 of Set 5 | kamenka
# Processing Record 31 of Set 5 | cuaspud
# Processing Record 32 of Set 5 | kokkola
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | umm kaddadah
# Processing Record 35 of Set 5 | salvador
# Processing Record 36 of Set 5 | wabag
# Processing Record 37 of Set 5 | ancud
# Processing Record 38 of Set 5 | ushtobe
# Processing Record 39 of Set 5 | broome
# Processing Record 40 of Set 5 | kuching
# Processing Record 41 of Set 5 | huarmey
# Processing Record 42 of Set 5 | goundam
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | dakar
# Processing Record 45 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 5 | galesong
# Processing Record 47 of Set 5 | norfolk
# Processing Record 48 of Set 5 | cavalcante
# Processing Record 49 of Set 5 | forestville
# Processing Record 50 of Set 5 | besancon
# Processing Record 1 of Set 6 | meulaboh
# Processing Record 2 of Set 6 | srednekolymsk
# Processing Record 3 of Set 6 | lebu
# Processing Record 4 of Set 6 | ojinaga
# Processing Record 5 of Set 6 | sassandra
# Processing Record 6 of Set 6 | lokosovo
# Processing Record 7 of Set 6 | melilla
# Processing Record 8 of Set 6 | port elizabeth
# Processing Record 9 of Set 6 | solnechnyy
# Processing Record 10 of Set 6 | tasiilaq
# Processing Record 11 of Set 6 | mount isa
# Processing Record 12 of Set 6 | savalou
# Processing Record 13 of Set 6 | rawson
# Processing Record 14 of Set 6 | bhinmal
# Processing Record 15 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 16 of Set 6 | pafos
# Processing Record 17 of Set 6 | san pedro de cajas
# Processing Record 18 of Set 6 | port hawkesbury
# Processing Record 19 of Set 6 | kharitonovo
# Processing Record 20 of Set 6 | mar del plata
# Processing Record 21 of Set 6 | castro
# Processing Record 22 of Set 6 | selje
# Processing Record 23 of Set 6 | mahebourg
# Processing Record 24 of Set 6 | trat
# Processing Record 25 of Set 6 | touros
# Processing Record 26 of Set 6 | gari
# Processing Record 27 of Set 6 | nizhneudinsk
# Processing Record 28 of Set 6 | neepawa
# Processing Record 29 of Set 6 | kuytun
# Processing Record 30 of Set 6 | ulaangom
# Processing Record 31 of Set 6 | sioux lookout
# Processing Record 32 of Set 6 | tiznit
# Processing Record 33 of Set 6 | huejuquilla el alto
# Processing Record 34 of Set 6 | longyearbyen
# Processing Record 35 of Set 6 | buin
# Processing Record 36 of Set 6 | gemena
# Processing Record 37 of Set 6 | san antonio
# Processing Record 38 of Set 6 | cayenne
# Processing Record 39 of Set 6 | tsogni
# Processing Record 40 of Set 6 | shibarghan
# City not found. Skipping...
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | meiktila
# Processing Record 43 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 44 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 6 | taoudenni
# Processing Record 46 of Set 6 | lopatino
# Processing Record 47 of Set 6 | pilar
# Processing Record 48 of Set 6 | sungaipenuh
# Processing Record 49 of Set 6 | finote selam
# Processing Record 50 of Set 6 | fortuna
# Processing Record 1 of Set 7 | zhigansk
# Processing Record 2 of Set 7 | maiduguri
# Processing Record 3 of Set 7 | inirida
# Processing Record 4 of Set 7 | veraval
# Processing Record 5 of Set 7 | esperance
# Processing Record 6 of Set 7 | tabou
# Processing Record 7 of Set 7 | loandjili
# Processing Record 8 of Set 7 | port hueneme
# Processing Record 9 of Set 7 | nouadhibou
# Processing Record 10 of Set 7 | viedma
# Processing Record 11 of Set 7 | luderitz
# Processing Record 12 of Set 7 | joao pinheiro
# Processing Record 13 of Set 7 | kollam
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 7 | abu dhabi
# Processing Record 17 of Set 7 | puerto escondido
# Processing Record 18 of Set 7 | wanning
# Processing Record 19 of Set 7 | sanford
# Processing Record 20 of Set 7 | nizhniy bestyakh
# Processing Record 21 of Set 7 | korla
# Processing Record 22 of Set 7 | port-gentil
# Processing Record 23 of Set 7 | umm lajj
# Processing Record 24 of Set 7 | nishihara
# Processing Record 25 of Set 7 | ilheus
# Processing Record 26 of Set 7 | mayumba
# Processing Record 27 of Set 7 | baherden
# Processing Record 28 of Set 7 | faya
# Processing Record 29 of Set 7 | wyoming
# Processing Record 30 of Set 7 | andenes
# Processing Record 31 of Set 7 | marrakesh
# Processing Record 32 of Set 7 | flowing wells
# Processing Record 33 of Set 7 | surgut
# Processing Record 34 of Set 7 | noumea
# Processing Record 35 of Set 7 | benguela
# Processing Record 36 of Set 7 | dumas
# Processing Record 37 of Set 7 | awjilah
# Processing Record 38 of Set 7 | katobu
# Processing Record 39 of Set 7 | sarangani
# Processing Record 40 of Set 7 | imbituba
# Processing Record 41 of Set 7 | qingdao
# Processing Record 42 of Set 7 | akdepe
# Processing Record 43 of Set 7 | pisco
# Processing Record 44 of Set 7 | bagan
# Processing Record 45 of Set 7 | san quintin
# Processing Record 46 of Set 7 | labuhan
# Processing Record 47 of Set 7 | nemuro
# Processing Record 48 of Set 7 | ahome
# Processing Record 49 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 50 of Set 7 | magnitogorsk
# Processing Record 1 of Set 8 | puerto maldonado
# Processing Record 2 of Set 8 | husavik
# Processing Record 3 of Set 8 | general jose eduvigis diaz
# Processing Record 4 of Set 8 | nanortalik
# Processing Record 5 of Set 8 | olinda
# Processing Record 6 of Set 8 | kalga
# Processing Record 7 of Set 8 | yerofey pavlovich
# Processing Record 8 of Set 8 | auki
# Processing Record 9 of Set 8 | souillac
# Processing Record 10 of Set 8 | winnemucca
# Processing Record 11 of Set 8 | dinard
# Processing Record 12 of Set 8 | clyde river
# Processing Record 13 of Set 8 | yabelo
# Processing Record 14 of Set 8 | lahaina
# Processing Record 15 of Set 8 | bowen
# Processing Record 16 of Set 8 | julana
# City not found. Skipping...
# Processing Record 17 of Set 8 | port hardy
# Processing Record 18 of Set 8 | ende
# Processing Record 19 of Set 8 | along
# Processing Record 20 of Set 8 | leshukonskoye
# Processing Record 21 of Set 8 | kolokani
# Processing Record 22 of Set 8 | nikolayevsk-na-amure
# Processing Record 23 of Set 8 | creel
# Processing Record 24 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | saint george
# Processing Record 26 of Set 8 | ruwi
# Processing Record 27 of Set 8 | pahrump
# Processing Record 28 of Set 8 | leningradskiy
# Processing Record 29 of Set 8 | laguna de perlas
# Processing Record 30 of Set 8 | erice
# Processing Record 31 of Set 8 | acajutla
# Processing Record 32 of Set 8 | killarney
# Processing Record 33 of Set 8 | kavaratti
# Processing Record 34 of Set 8 | saint-augustin
# Processing Record 35 of Set 8 | boulder city
# Processing Record 36 of Set 8 | itarema
# Processing Record 37 of Set 8 | aden
# Processing Record 38 of Set 8 | axim
# Processing Record 39 of Set 8 | mirnyy
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 8 | kaeo
# Processing Record 43 of Set 8 | pangkalanbuun
# Processing Record 44 of Set 8 | skjervoy
# Processing Record 45 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 46 of Set 8 | uglovskoye
# Processing Record 47 of Set 8 | narsaq
# Processing Record 48 of Set 8 | saint-junien
# Processing Record 49 of Set 8 | okhotsk
# Processing Record 50 of Set 8 | abonnema
# Processing Record 1 of Set 9 | verkhnevilyuysk
# Processing Record 2 of Set 9 | porto belo
# Processing Record 3 of Set 9 | machali
# Processing Record 4 of Set 9 | normandin
# Processing Record 5 of Set 9 | qianan
# Processing Record 6 of Set 9 | khandyga
# Processing Record 7 of Set 9 | half moon bay
# Processing Record 8 of Set 9 | gunjur
# Processing Record 9 of Set 9 | bandiagara
# Processing Record 10 of Set 9 | roald
# Processing Record 11 of Set 9 | amapa
# Processing Record 12 of Set 9 | flin flon
# Processing Record 13 of Set 9 | sinnamary
# Processing Record 14 of Set 9 | scarborough
# Processing Record 15 of Set 9 | talcahuano
# Processing Record 16 of Set 9 | sibolga
# Processing Record 17 of Set 9 | makakilo city
# Processing Record 18 of Set 9 | teguldet
# Processing Record 19 of Set 9 | myitkyina
# Processing Record 20 of Set 9 | tete
# Processing Record 21 of Set 9 | north myrtle beach
# Processing Record 22 of Set 9 | peruibe
# Processing Record 23 of Set 9 | kemi
# Processing Record 24 of Set 9 | peniche
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | pontianak
# Processing Record 27 of Set 9 | sterling heights
# Processing Record 28 of Set 9 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 9 | ebnat-kappel
# Processing Record 30 of Set 9 | mae hong son
# Processing Record 31 of Set 9 | manali
# Processing Record 32 of Set 9 | chernyshevskiy
# Processing Record 33 of Set 9 | saurimo
# Processing Record 34 of Set 9 | quatre cocos
# Processing Record 35 of Set 9 | isangel
# Processing Record 36 of Set 9 | khash
# Processing Record 37 of Set 9 | banamba
# Processing Record 38 of Set 9 | olafsvik
# Processing Record 39 of Set 9 | gat
# Processing Record 40 of Set 9 | griffith
# Processing Record 41 of Set 9 | pacific grove
# Processing Record 42 of Set 9 | raudeberg
# Processing Record 43 of Set 9 | haines junction
# Processing Record 44 of Set 9 | nipawin
# Processing Record 45 of Set 9 | lerwick
# Processing Record 46 of Set 9 | rovaniemi
# Processing Record 47 of Set 9 | bilibino
# Processing Record 48 of Set 9 | helena
# Processing Record 49 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 50 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 1 of Set 10 | port lincoln
# Processing Record 2 of Set 10 | male
# Processing Record 3 of Set 10 | avera
# Processing Record 4 of Set 10 | chitipa
# Processing Record 5 of Set 10 | anderson
# Processing Record 6 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 10 | celestun
# Processing Record 8 of Set 10 | yaan
# Processing Record 9 of Set 10 | ponta delgada
# Processing Record 10 of Set 10 | sao joao evangelista
# Processing Record 11 of Set 10 | yarim
# Processing Record 12 of Set 10 | vila franca do campo
# Processing Record 13 of Set 10 | newport
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | miri
# Processing Record 16 of Set 10 | hoa binh
# Processing Record 17 of Set 10 | beringovskiy
# Processing Record 18 of Set 10 | voskresenskoye
# Processing Record 19 of Set 10 | fakel
# Processing Record 20 of Set 10 | pombas
# Processing Record 21 of Set 10 | la ronge
# Processing Record 22 of Set 10 | karaman
# Processing Record 23 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 10 | gizo
# Processing Record 25 of Set 10 | palu
# Processing Record 26 of Set 10 | egvekinot
# Processing Record 27 of Set 10 | daur
# Processing Record 28 of Set 10 | inta
# Processing Record 29 of Set 10 | taitung
# City not found. Skipping...
# Processing Record 30 of Set 10 | sofiysk
# City not found. Skipping...
# Processing Record 31 of Set 10 | bida
# City not found. Skipping...
# Processing Record 32 of Set 10 | udarnyy
# City not found. Skipping...
# Processing Record 33 of Set 10 | chiang rai
# City not found. Skipping...
# Processing Record 34 of Set 10 | mersing
# City not found. Skipping...
# Processing Record 35 of Set 10 | varzob
# Processing Record 36 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 37 of Set 10 | cascais
# Processing Record 38 of Set 10 | awbari
# Processing Record 39 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 40 of Set 10 | tergnier
# Processing Record 41 of Set 10 | voh
# Processing Record 42 of Set 10 | montepuez
# Processing Record 43 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 44 of Set 10 | taungdwingyi
# Processing Record 45 of Set 10 | ust-koksa
# Processing Record 46 of Set 10 | tall kayf
# Processing Record 47 of Set 10 | yashkino
# Processing Record 48 of Set 10 | miramar
# Processing Record 49 of Set 10 | praia
# Processing Record 50 of Set 10 | margate
# Processing Record 1 of Set 11 | berlevag
# Processing Record 2 of Set 11 | camapua
# Processing Record 3 of Set 11 | uvat
# Processing Record 4 of Set 11 | santo domingo
# Processing Record 5 of Set 11 | saint-pierre
# Processing Record 6 of Set 11 | virginia beach
# Processing Record 7 of Set 11 | sahuaripa
# Processing Record 8 of Set 11 | sakakah
# Processing Record 9 of Set 11 | xai-xai
# Processing Record 10 of Set 11 | hilchenbach
# Processing Record 11 of Set 11 | aginskoye
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | gaoua
# Processing Record 14 of Set 11 | chara
# Processing Record 15 of Set 11 | kampot
# Processing Record 16 of Set 11 | de aar
# Processing Record 17 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 18 of Set 11 | pedra
# Processing Record 19 of Set 11 | kaka
# Processing Record 20 of Set 11 | tateyama
# Processing Record 21 of Set 11 | shimoda
# Processing Record 22 of Set 11 | balakhta
# Processing Record 23 of Set 11 | yar-sale
# Processing Record 24 of Set 11 | nioro
# Processing Record 25 of Set 11 | plettenberg bay
# Processing Record 26 of Set 11 | halifax
# Processing Record 27 of Set 11 | ilhabela
# Processing Record 28 of Set 11 | namie
# Processing Record 29 of Set 11 | nizhniy kuranakh
# Processing Record 30 of Set 11 | powell
# Processing Record 31 of Set 11 | iskilip
# Processing Record 32 of Set 11 | ilulissat
# Processing Record 33 of Set 11 | coahuayana
# Processing Record 34 of Set 11 | wahran
# City not found. Skipping...
# Processing Record 35 of Set 11 | tautira
# Processing Record 36 of Set 11 | porto novo
# Processing Record 37 of Set 11 | severo-kurilsk
# Processing Record 38 of Set 11 | chon daen
# Processing Record 39 of Set 11 | great yarmouth
# Processing Record 40 of Set 11 | russell
# Processing Record 41 of Set 11 | boa vista
# Processing Record 42 of Set 11 | calabar
# Processing Record 43 of Set 11 | lata
# Processing Record 44 of Set 11 | gazli
# Processing Record 45 of Set 11 | maturin
# Processing Record 46 of Set 11 | sur
# Processing Record 47 of Set 11 | merrill
# Processing Record 48 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 11 | grand gaube
# Processing Record 50 of Set 11 | la union
# Processing Record 1 of Set 12 | la crosse
# Processing Record 2 of Set 12 | semporna
# Processing Record 3 of Set 12 | kinablangan
# Processing Record 4 of Set 12 | cody
# Processing Record 5 of Set 12 | wilmington
# Processing Record 6 of Set 12 | cap malheureux
# Processing Record 7 of Set 12 | metlaltoyuca
# Processing Record 8 of Set 12 | hurricane
# Processing Record 9 of Set 12 | jiutai
# Processing Record 10 of Set 12 | fort nelson
# Processing Record 11 of Set 12 | sao joao da barra
# Processing Record 12 of Set 12 | dongsheng
# Processing Record 13 of Set 12 | dangriga
# Processing Record 14 of Set 12 | chimbote
# Processing Record 15 of Set 12 | okha
# Processing Record 16 of Set 12 | zimovniki
# Processing Record 17 of Set 12 | sattankulam
# City not found. Skipping...
# Processing Record 18 of Set 12 | matara
# Processing Record 19 of Set 12 | buraydah
# Processing Record 20 of Set 12 | victoria
# Processing Record 21 of Set 12 | emerald
# Processing Record 22 of Set 12 | warmbad
# Processing Record 23 of Set 12 | adrar
# Processing Record 24 of Set 12 | tahta
# Processing Record 25 of Set 12 | tirano
# Processing Record 26 of Set 12 | chapais
# Processing Record 27 of Set 12 | samarai
# Processing Record 28 of Set 12 | bubaque
# Processing Record 29 of Set 12 | hualmay
# Processing Record 30 of Set 12 | gornja radgona
# Processing Record 31 of Set 12 | mokokchung
# Processing Record 32 of Set 12 | kizukuri
# Processing Record 33 of Set 12 | tual
# Processing Record 34 of Set 12 | alausi
# Processing Record 35 of Set 12 | jumla
# Processing Record 36 of Set 12 | jacareacanga
# Processing Record 37 of Set 12 | tongling
# Processing Record 38 of Set 12 | kem
# Processing Record 39 of Set 12 | lexington
# Processing Record 40 of Set 12 | todos santos
# Processing Record 41 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 12 | tura
# Processing Record 43 of Set 12 | barbosa ferraz
# Processing Record 44 of Set 12 | calvinia
# Processing Record 45 of Set 12 | ambon
# Processing Record 46 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 47 of Set 12 | les cayes
# Processing Record 48 of Set 12 | smithers
# Processing Record 49 of Set 12 | kalaleh
# Processing Record 50 of Set 12 | san cristobal
# Processing Record 1 of Set 13 | sorong
# Processing Record 2 of Set 13 | odesskoye
# Processing Record 3 of Set 13 | salym
# Processing Record 4 of Set 13 | roanoke rapids
# Processing Record 5 of Set 13 | bartica
# Processing Record 6 of Set 13 | nalut
# Processing Record 7 of Set 13 | kahului
# Processing Record 8 of Set 13 | kushima
# Processing Record 9 of Set 13 | carbondale
# Processing Record 10 of Set 13 | nokaneng
# Processing Record 11 of Set 13 | mackay
# Processing Record 12 of Set 13 | mazatlan
# Processing Record 13 of Set 13 | acoua
# Processing Record 14 of Set 13 | yantal
# Processing Record 15 of Set 13 | mandan
# Processing Record 16 of Set 13 | yumen
# Processing Record 17 of Set 13 | chulym
# Processing Record 18 of Set 13 | pochutla
# Processing Record 19 of Set 13 | boralday
# Processing Record 20 of Set 13 | vanimo
# Processing Record 21 of Set 13 | muhos
# Processing Record 22 of Set 13 | sechura
# Processing Record 23 of Set 13 | vila
# Processing Record 24 of Set 13 | pemangkat
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 13 | yatou
# Processing Record 28 of Set 13 | murray bridge
# Processing Record 29 of Set 13 | plouzane
# Processing Record 30 of Set 13 | los llanos de aridane
# Processing Record 31 of Set 13 | vangaindrano
# Processing Record 32 of Set 13 | xingtai
# Processing Record 33 of Set 13 | libenge
# Processing Record 34 of Set 13 | cilegon
# Processing Record 35 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 13 | linhares
# Processing Record 37 of Set 13 | camopi
# Processing Record 38 of Set 13 | tomatlan
# Processing Record 39 of Set 13 | bellinge
# Processing Record 40 of Set 13 | barretos
# Processing Record 41 of Set 13 | sao borja
# Processing Record 42 of Set 13 | emba
# Processing Record 43 of Set 13 | udomlya
# Processing Record 44 of Set 13 | pontes e lacerda
# Processing Record 45 of Set 13 | fraga
# Processing Record 46 of Set 13 | martapura
# Processing Record 47 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 13 | simao
# Processing Record 49 of Set 13 | riyadh
# Processing Record 50 of Set 13 | fairbanks
# Processing Record 1 of Set 14 | pangody
# Processing Record 2 of Set 14 | mahina
# Processing Record 3 of Set 14 | novobirilyussy
# Processing Record 4 of Set 14 | iquitos
# Processing Record 5 of Set 14 | uige
# Processing Record 6 of Set 14 | banjar
# Processing Record 7 of Set 14 | okhansk
# Processing Record 8 of Set 14 | tiverton
# Processing Record 9 of Set 14 | mariental
# Processing Record 10 of Set 14 | adeje
# Processing Record 11 of Set 14 | yamada
# Processing Record 12 of Set 14 | ziarat
# Processing Record 13 of Set 14 | mopipi
# Processing Record 14 of Set 14 | aksu
# Processing Record 15 of Set 14 | guilin
# Processing Record 16 of Set 14 | kieta
# Processing Record 17 of Set 14 | cuauhtemoc
# Processing Record 18 of Set 14 | ferme-neuve
# Processing Record 19 of Set 14 | timizart
# Processing Record 20 of Set 14 | hervey bay
# Processing Record 21 of Set 14 | kletskaya
# Processing Record 22 of Set 14 | wamba
# Processing Record 23 of Set 14 | shetpe
# Processing Record 24 of Set 14 | serpa
# Processing Record 25 of Set 14 | cherskiy
# Processing Record 26 of Set 14 | acarau
# Processing Record 27 of Set 14 | carlsbad
# Processing Record 28 of Set 14 | vershino-shakhtaminskiy
# Processing Record 29 of Set 14 | rangpur
# Processing Record 30 of Set 14 | santa fe
# Processing Record 31 of Set 14 | ashland
# Processing Record 32 of Set 14 | san bartolome de tirajana
# Processing Record 33 of Set 14 | muros
# Processing Record 34 of Set 14 | teguise
# Processing Record 35 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 14 | karsun
# Processing Record 37 of Set 14 | bantogon
# Processing Record 38 of Set 14 | yining
# Processing Record 39 of Set 14 | saint-joseph
# Processing Record 40 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 41 of Set 14 | rantepao
# Processing Record 42 of Set 14 | ormara
# Processing Record 43 of Set 14 | vao
# Processing Record 44 of Set 14 | niles
# Processing Record 45 of Set 14 | othonoi
# City not found. Skipping...
# Processing Record 46 of Set 14 | khairpur
# Processing Record 47 of Set 14 | stokmarknes
# Processing Record 48 of Set 14 | fort smith
# Processing Record 49 of Set 14 | san juan
# Processing Record 50 of Set 14 | bosaso
# Processing Record 1 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 15 | vallenar
# Processing Record 4 of Set 15 | deep river
# Processing Record 5 of Set 15 | gariaband
# Processing Record 6 of Set 15 | lokoja
# Processing Record 7 of Set 15 | karatuzskoye
# Processing Record 8 of Set 15 | estelle
# Processing Record 9 of Set 15 | bilma
# Processing Record 10 of Set 15 | komsomolskiy
# Processing Record 11 of Set 15 | ambilobe
# Processing Record 12 of Set 15 | le port
# Processing Record 13 of Set 15 | udachnyy
# Processing Record 14 of Set 15 | whyalla
# Processing Record 15 of Set 15 | saratoga springs
# Processing Record 16 of Set 15 | khani
# Processing Record 17 of Set 15 | fare
# Processing Record 18 of Set 15 | beloha
# Processing Record 19 of Set 15 | darhan
# Processing Record 20 of Set 15 | soc trang
# Processing Record 21 of Set 15 | sabla
# Processing Record 22 of Set 15 | santa rosa
# Processing Record 23 of Set 15 | kondinskoye
# Processing Record 24 of Set 15 | gasa
# Processing Record 25 of Set 15 | camocim
# Processing Record 26 of Set 15 | karatau
# Processing Record 27 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 15 | richards bay
# Processing Record 29 of Set 15 | znamenskoye
# Processing Record 30 of Set 15 | kirakira
# Processing Record 31 of Set 15 | senanga
# Processing Record 32 of Set 15 | asau
# Processing Record 33 of Set 15 | mogadishu
# Processing Record 34 of Set 15 | bonthe
# Processing Record 35 of Set 15 | sinjar
# Processing Record 36 of Set 15 | jalu
# Processing Record 37 of Set 15 | leirvik
# Processing Record 38 of Set 15 | armenion
# City not found. Skipping...
# Processing Record 39 of Set 15 | sawtell
# Processing Record 40 of Set 15 | catuday
# Processing Record 41 of Set 15 | sterling
# Processing Record 42 of Set 15 | marawi
# Processing Record 43 of Set 15 | saint-michel-des-saints
# Processing Record 44 of Set 15 | baoqing
# Processing Record 45 of Set 15 | vila do maio
# Processing Record 46 of Set 15 | zhengjiatun
# Processing Record 47 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 48 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 49 of Set 15 | yeppoon
# Processing Record 50 of Set 15 | namibe
# Processing Record 1 of Set 16 | vardo
# Processing Record 2 of Set 16 | pita
# Processing Record 3 of Set 16 | chicama
# Processing Record 4 of Set 16 | general cepeda
# Processing Record 5 of Set 16 | neiafu
# Processing Record 6 of Set 16 | mizdah
# Processing Record 7 of Set 16 | murupara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow  71.2906 -156.7887     -4.00        77          40
# 1    Nikolskoye  59.7035   30.7861     19.40        93          75
# 2          Gedo   9.0167   37.4500     51.30        55          62
# 3       Rikitea -23.1203 -134.9692     78.75        74          11
# 4    Oranjemund -28.5500   16.4333     61.23        92           0
# 5     Jamestown  42.0970  -79.2353     30.99       100          90
# 6  Punta Arenas -53.1500  -70.9167     53.60        66          90
# 7     Inhambane -23.8650   35.3833     77.11        92         100
# 8   New Norfolk -42.7826  147.0587     69.80        43          40
# 9    Port Blair  11.6667   92.7500     82.24        72          49
#
#    Wind Speed Country                 Date
# 0       14.97      US  2021-01-18 02:48:25
# 1        6.71      RU  2021-01-18 02:51:15
# 2        3.60      ET  2021-01-18 02:58:05
# 3        9.89      PF  2021-01-18 02:50:50
# 4        2.21      NA  2021-01-18 02:58:05
# 5        9.22      US  2021-01-18 02:58:06
# 6       16.11      CL  2021-01-18 02:57:28
# 7       13.73      MZ  2021-01-18 02:58:06
# 8       25.32      AU  2021-01-18 02:58:06
# 9       19.55      IN  2021-01-18 02:58:07

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
